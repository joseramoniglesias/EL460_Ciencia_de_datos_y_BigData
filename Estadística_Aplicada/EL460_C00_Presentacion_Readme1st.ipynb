# %% [markdown]
# # Ciencia de datos y BigData<a class="tocSkip">
# ### Ingenieria Electrónica <a class="tocSkip">
# ### Universidad Popular del Cesar <a class="tocSkip">
# ### Prof.: Jose Ramón Iglesias Gamarra - [https://github.com/joseramoniglesias/](https://github.com/joseramoniglesias/) <a class="tocSkip">
#   **joseiglesias@unicesar.edu.co**
#
# <h1 align="center">Analítica de datos para la toma de decisiones basadas en información</h1>
# <h1 align="center">Presentación del curso</h1>
# <h1 align="center">2026</h1>

# %% [markdown]
# ***
#  <td>Text provided under a Creative Commons Attribution license, CC-BY. All code is made available under the FSF-approved MIT license.
# </table>
#
# ***

# %% [markdown]
# ## Navegación en el curso

# %% [markdown]
# Si ya tiene conocimientos en el ecosistema Python (lenguaje, Numpy, Pandas, Matplotlib, etc...), puede ir directamente a los contenidos específicos en estadística, empezando por el de [Estadística Univariante](https://github.com/joseramoniglesias/EL460_Ciencia_de_datos_y_BigData/blob/main/Estad%C3%ADstica_Aplicada/EL460_C01_Estadistica_Univariante.ipynb). Si es su primer contacto con el ecosistema Python, o nunca ha tenido la oportunidad de aprender un lenguaje de programación, se recomienda empezar por el [EL460_CrashCourse01_Python.ipynb](https://github.com/joseramoniglesias/EL460_Ciencia_de_datos_y_BigData/blob/main/Estad%C3%ADstica_Aplicada/EL460_CrashCourse01_Python.ipynb) y luego retomar los contenidos de estadística.

# %% [markdown]
# ## Objetivo de formación

# %% [markdown]
# Fortalecer e implementar el razonamiento estadístico en la gestión y análisis de datos a través del uso de Python.

# %% [markdown]
# ## Intensidad

# %% [markdown]
# Se espera que el interesado en realizar este curso invierta entre 40 y 64 horas de su tiempo para finalizarlo.

# %% [markdown]
# ## Modalidad

# %% [markdown]
# Esta formación se desarrollará siguiendo las clases del curso EL_460 Ciencia de Datos del Programa de Ingeniería Electrónica de la Universidad Popular del Cesar, con clases magistrales por parte del docenete con actividades a ser desarrolladas por los asistentes de forma autónoma e independiente.

# %% [markdown]
# ## Contenido

# %% [markdown]
# ### Módulo 1: Estadística univariante

# %% [markdown]
# - [Introducción a conceptos básicos de estadística univariante](https://github.com/joseramoniglesias/EL460_Ciencia_de_datos_y_BigData/blob/main/Estad%C3%ADstica_Aplicada/EL460_C01_Estadistica_Univariante.ipynb): Descripción gráfica, visual y tabular de los datos, Indicadores de centralidad, dispersión y forma, y su interpretación.
# <p>&nbsp;</p>
#
# - [Análisis de normalidad](https://github.com/joseramoniglesias/EL460_Ciencia_de_datos_y_BigData/blob/main/Estad%C3%ADstica_Aplicada/EL460_C02_Analisis_Normalidad.ipynb) y Modelos Probabilísticos, Estimación puntal de indicadores (parámetros) e intervalos de confianza, Pruebas de hipótesis paramétricas y no paramétricas.

# %% [markdown]
# ### Módulo 2: Modelos de predicción y pronóstico

# %% [markdown]
# - [Modelos de predicción y pronóstico](https://github.com/joseramoniglesias/EL460_Ciencia_de_datos_y_BigData/blob/main/Estad%C3%ADstica_Aplicada/EL460_C03_Modelos_Prediccion_Pronostico.ipynb): Visualización de datos, Correlaciónes, Modelo de regresión lineal, Métodos estadísticos de selección de variables importantes e identificación de información redundante, Validación y significancia.
# <p>&nbsp;</p>
#
# - [Series de tiempo](https://github.com/joseramoniglesias/EL460_Ciencia_de_datos_y_BigData/blob/main/Estad%C3%ADstica_Aplicada/EL460_C04_TimeSeries_Outliers.ipynb) e Identificación de datos raros (outliers), Regresión robusta.

# %% [markdown]
# ### Módulo 3: Estadística multivariante

# %% [markdown]
# - [Estadística multivariante](https://github.com/joseramoniglesias/EL460_Ciencia_de_datos_y_BigData/blob/main/Estad%C3%ADstica_Aplicada/EL460_C05_Estad%C3%ADstica_multivariante.ipynb): Visualización de datos multivariantes, Indicadores de centralidad, dispersión y forma, Similaridad de individuos y registros (Distancia estadística), Outliers multivariantes, Componentes principales, Clustering, Clasificación supervisada de registros.

# %% [markdown]
# ## Sesiones clase a clase

# %% [markdown]
# | Sesión  |                 Módulo                |Horas|
# |:-------:|:-------------------------------------|:---:|
# |  1      | Ecosistema Python: Crash course                                            |  4  |
# |  2      | ***Taller de repaso: ecosistema Python (asincrónico)***                    |  4  |
# |  3      | Estadística Univariante                                                    |  4  |
# |  4      | Análisis de Normalidad                                                     |  4  |
# |  5      | Modelos de Predicción y Pronóstico                                         |  4  |
# |  6      | ***Taller de repaso: Estadística Univariante y Modelos de predicción (asincrónico)***  |  4  |
# |  7      | Series de tiempo y detección de Outliers                                   |  4  |
# |  8      | Estadística multivariante I                                                |  4  |
# |  9      | Estadística multivariante II                                               |  4  |
# | 10      | ***Taller de repaso: General***                                            |  4  |
# |         | ***Total horas***                                                       |***40***|

# %% [markdown]
# ## Recursos adicionales

# %% [markdown]
# Como complemento al curso, se han desarrollado una serie de documentos (notebooks) tipo cursos rápidos (crash-courses) que le permitirán al estudiante adquirir las habilidades necesarias y suficientes para abordar los temas del curso. Se invita a los estudiantes a que revisen esta documentación:
#
# - [CrashCourse01_Python.ipynb](https://github.com/joseramoniglesias/EL460_Ciencia_de_datos_y_BigData/blob/main/Estad%C3%ADstica_Aplicada/EL460_CrashCourse01_Python.ipynb)
# <p>&nbsp;</p>
#
# - [CrashCourse02_Numpy.ipynb](https://github.com/joseramoniglesias/EL460_Ciencia_de_datos_y_BigData/blob/main/Estad%C3%ADstica_Aplicada/EL460_CrashCourse02_Numpy.ipynb)
# <p>&nbsp;</p>
#
# - [CrashCourse03_Matplotlib.ipynb](https://github.com/joseramoniglesias/EL460_Ciencia_de_datos_y_BigData/blob/main/Estad%C3%ADstica_Aplicada/EL460_CrashCourse03_Matplotlib.ipynb)
# <p>&nbsp;</p>
#
# - [CrashCourse04_Pandas.ipynb](https://github.com/joseramoniglesias/EL460_Ciencia_de_datos_y_BigData/blob/main/Estad%C3%ADstica_Aplicada/EL460_CrashCourse04_Pandas.ipynb)
# <p>&nbsp;</p>
#
# - [CrashCourse06_NumerosAleatorios.ipynb](https://github.com/joseramoniglesias/EL460_Ciencia_de_datos_y_BigData/blob/main/Estad%C3%ADstica_Aplicada/EL460_CrashCourse06_NumerosAleatorios.ipynb)
# <p>&nbsp;</p>
#
# - [CrashCourse07_DistribucionesProbabilidad.ipynb](https://github.com/joseramoniglesias/EL460_Ciencia_de_datos_y_BigData/blob/main/Estad%C3%ADstica_Aplicada/EL460_CrashCourse07_DistribucionesProbabilidad.ipynb)

# %% [markdown]
# ## Metodología

# %% [markdown]
# El curso se desarrolla con diferentes estrategias pedagógicas, entre otras:
# - Clases Magistrales en modalidad remota (E-learning)
# - Talleres para desarrollar en diferentes plataformas de trabajo (Python, Jupyter Notebook, Google Colab)

# %% [markdown]
# ## Cibergrafía

# %% [markdown]
# A lo largo del curso se usarán los siguientes recursos computacionales:
#
#
# - [Python](https://www.python.org/)
# <p>&nbsp;</p>
#
# - [Numpy](https://numpy.org/)
# <p>&nbsp;</p>
#
# - [Matplotlib](https://matplotlib.org/)
# <p>&nbsp;</p>
#
# - [Pandas](https://pandas.pydata.org/)
# <p>&nbsp;</p>
#
# - [Jupyter](https://jupyter.org/)
# <p>&nbsp;</p>
#
# - [Anaconda](https://anaconda.org/)
# <p>&nbsp;</p>
#
# - [Google Colab](https://colab.research.google.com/)
# <p>&nbsp;</p>
#
# - [Github](https://github.com/carlosalvarezh)
# <p>&nbsp;</p>
#
# - [Visual Studio Code](https://code.visualstudio.com/)
